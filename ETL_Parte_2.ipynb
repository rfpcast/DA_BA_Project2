# %% [markdown]
# # ETL - Segunda parte

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_1_ETL2 = pd.read_csv('Data\homicidios_2.csv')

# %%
df_gcba = pd.read_excel('Data\gcba_pob_comunas_17.xlsx')

# %%
print(len(df_1_ETL2))
print(df_1_ETL2.isnull().sum())
print(df_1_ETL2.columns)

df_1_ETL2.head(10)
# Out:
# 696
# Unnamed: 0               0
# ID                       0
# N_VICTIMAS               0
# FECHA                    0
# AAAA                     0
# MM                       0
# DD                       0
# HORA                     0
# HH                       0
# LUGAR_DEL_HECHO          0
# TIPO_DE_CALLE            0
# Calle                    0
# Cruce                    0
# Dirección Normalizada    0
# COMUNA                   0
# PARTICIPANTES            0
# VICTIMA                  0
# ACUSADO                  0
# dtype: int64
# Index(['Unnamed: 0', 'ID', 'N_VICTIMAS', 'FECHA', 'AAAA', 'MM', 'DD', 'HORA',
#        'HH', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'Calle', 'Cruce',
#        'Dirección Normalizada', 'COMUNA', 'PARTICIPANTES', 'VICTIMA',
#        'ACUSADO'],
#       dtype='object')
#    Unnamed: 0         ID  N_VICTIMAS       FECHA  AAAA  MM  DD      HORA  HH  \
# 0           0  2016-0001           1  2016-01-01  2016   1   1  04:00:00   4
# 1           1  2016-0002           1  2016-01-02  2016   1   2  01:15:00   1
# 2           2  2016-0003           1  2016-01-03  2016   1   3  07:00:00   7
# 3           3  2016-0004           1  2016-01-10  2016   1  10  00:00:00   0
# 4           4  2016-0005           1  2016-01-21  2016   1  21  05:20:00   5
# 5           5  2016-0008           1  2016-01-24  2016   1  24  18:30:00  18
# 6           6  2016-0009           1  2016-01-24  2016   1  24  19:10:00  19
# 7           7  2016-0010           1  2016-01-29  2016   1  29  15:20:00  15
# 8           8  2016-0012           1  2016-02-08  2016   2   8  01:20:00   1
# 9           9  2016-0013           1  2016-02-10  2016   2  10  11:30:00  11
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE              Calle  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA   PIEDRA BUENA AV.
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ     PAZ, GRAL. AV.
# 2                         AV ENTRE RIOS 2034       AVENIDA     ENTRE RIOS AV.
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA     LARRAZABAL AV.
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA       SAN JUAN AV.
# 5             AV 27 DE FEBRERO Y AV ESCALADA       AVENIDA  27 DE FEBRERO AV.
# 6               NOGOYA Y JOAQUIN V. GONZALES         CALLE             NOGOYA
# 7        AV GENERAL PAZ Y AV DE LOS CORRALES      GRAL PAZ     PAZ, GRAL. AV.
# 8         AV BELGRANO Y BERNARDO DE IRIGOYEN       AVENIDA       BELGRANO AV.
# 9                         AV ENTRE RIOS 1366       AVENIDA     ENTRE RIOS AV.
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                            Sin Cruce
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
# 5                         ESCALADA AV.
# 6                 GONZALEZ, JOAQUIN V.
# 7                  DE LOS CORRALES AV.
# 8                IRIGOYEN, BERNARDO DE
# 9                            Sin Cruce
#
#                                Dirección Normalizada  COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...       8
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.       9
# 2                                ENTRE RIOS AV. 2034       1
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.       8
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.       1
# 5                   27 DE FEBRERO AV. y ESCALADA AV.       8
# 6                      NOGOYA y GONZALEZ, JOAQUIN V.      11
# 7               PAZ, GRAL. AV. y DE LOS CORRALES AV.       9
# 8               BELGRANO AV. e IRIGOYEN, BERNARDO DE       1
# 9                                ENTRE RIOS AV. 1366       1
#
#       PARTICIPANTES VICTIMA      ACUSADO
# 0         MOTO-AUTO    MOTO         AUTO
# 1    AUTO-PASAJEROS    AUTO    PASAJEROS
# 2         MOTO-AUTO    MOTO         AUTO
# 3           MOTO-SD    MOTO           SD
# 4    MOTO-PASAJEROS    MOTO    PASAJEROS
# 5  MOTO-OBJETO FIJO    MOTO  OBJETO FIJO
# 6         MOTO-AUTO    MOTO         AUTO
# 7         MOTO-AUTO    MOTO         AUTO
# 8       MOTO-CARGAS    MOTO       CARGAS
# 9       PEATON-AUTO  PEATON         AUTO

# %%
df_1_ETL2_v2 = df_1_ETL2.copy()

# %%
df_1_ETL2_v3 = df_1_ETL2_v2.groupby(['AAAA', 'MM'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_v3))
print(df_1_ETL2_v3.isnull().sum())
print(df_1_ETL2_v3.columns)

df_1_ETL2_v3.head(10)
# Out:
# 72
# AAAA          0
# MM            0
# N_VICTIMAS    0
# dtype: int64
# Index(['AAAA', 'MM', 'N_VICTIMAS'], dtype='object')
#    AAAA  MM  N_VICTIMAS
# 0  2016   1           8
# 1  2016   2          12
# 2  2016   3          13
# 3  2016   4          11
# 4  2016   5           7
# 5  2016   6          14
# 6  2016   7          11
# 7  2016   8          13
# 8  2016   9          12
# 9  2016  10          12

# %%
df_1_ETL2_v3_Sem1 = df_1_ETL2_v3[(df_1_ETL2_v3['MM'] >= 1) & (df_1_ETL2_v3['MM'] <= 6)]
df_1_ETL2_v3_Sem2 = df_1_ETL2_v3[(df_1_ETL2_v3['MM'] >= 7) & (df_1_ETL2_v3['MM'] <= 12)]

# %%
df_1_ETL2_v3_Sem1.head(6)
# Out:
#    AAAA  MM  N_VICTIMAS
# 0  2016   1           8
# 1  2016   2          12
# 2  2016   3          13
# 3  2016   4          11
# 4  2016   5           7
# 5  2016   6          14

# %%
df_1_ETL2_v3_Sem2.head(6)
# Out:
#     AAAA  MM  N_VICTIMAS
# 6   2016   7          11
# 7   2016   8          13
# 8   2016   9          12
# 9   2016  10          12
# 10  2016  11          14
# 11  2016  12          19

# %%
df_1_ETL2_v3_Sem1 = df_1_ETL2_v3_Sem1.groupby(['AAAA'])['N_VICTIMAS'].sum().reset_index()

# %%
df_1_ETL2_v3_Sem1["Semestre"] = 1

# %%
df_1_ETL2_v3_Sem1
# Out:
#    AAAA  N_VICTIMAS  Semestre
# 0  2016          65         1
# 1  2017          69         1
# 2  2018          70         1
# 3  2019          57         1
# 4  2020          31         1
# 5  2021          55         1

# %%
df_1_ETL2_v3_Sem2 = df_1_ETL2_v3_Sem2.groupby(['AAAA'])['N_VICTIMAS'].sum().reset_index()

# %%
df_1_ETL2_v3_Sem2["Semestre"] = 2

# %%
df_1_ETL2_v3_Sem2
# Out:
#    AAAA  N_VICTIMAS  Semestre
# 0  2016          81         2
# 1  2017          71         2
# 2  2018          79         2
# 3  2019          47         2
# 4  2020          50         2
# 5  2021          42         2

# %%
df_1_ETL2_v4 = pd.merge(df_1_ETL2_v3_Sem1, df_1_ETL2_v3_Sem2, on='AAAA')

# %%
df_1_ETL2_v4
# Out:
#    AAAA  N_VICTIMAS_x  Semestre_x  N_VICTIMAS_y  Semestre_y
# 0  2016            65           1            81           2
# 1  2017            69           1            71           2
# 2  2018            70           1            79           2
# 3  2019            57           1            47           2
# 4  2020            31           1            50           2
# 5  2021            55           1            42           2

# %% [markdown]
# -------------------------------------------------------------------

# %%
df_gcba
# Out:
#     COMUNA  POBLACION
# 0        1     253271
# 1        2     149720
# 2        3     192763
# 3        4     238809
# 4        5     186956
# 5        6     184846
# 6        7     240607
# 7        8     226649
# 8        9     170605
# 9       10     170282
# 10      11     189986
# 11      12     213914
# 12      13     235967
# 13      14     226944
# 14      15     182409

# %%
df_gcba_v2 = df_gcba.copy()

df_gcba_v3 = df_gcba_v2['POBLACION'].sum()

# %%
df_gcba_v3
# Out:
# 3063728

# %% [markdown]
# --------------------------------------

# %%
df_1_ETL2_v5 = df_1_ETL2_v4.copy()

# %%
df_1_ETL2_v5["Poblacion total"] = df_gcba_v3

# %%
df_1_ETL2_v5
# Out:
#    AAAA  N_VICTIMAS_x  Semestre_x  N_VICTIMAS_y  Semestre_y  Poblacion total
# 0  2016            65           1            81           2          3063728
# 1  2017            69           1            71           2          3063728
# 2  2018            70           1            79           2          3063728
# 3  2019            57           1            47           2          3063728
# 4  2020            31           1            50           2          3063728
# 5  2021            55           1            42           2          3063728

# %%
df_1_ETL2_v5 = df_1_ETL2_v5.rename(columns={"N_VICTIMAS_x": "VICTIMAS S1", "N_VICTIMAS_y": "VICTIMAS S2"})

# %%
df_1_ETL2_v5
# Out:
#    AAAA  VICTIMAS S1  Semestre_x  VICTIMAS S2  Semestre_y  Poblacion total
# 0  2016           65           1           81           2          3063728
# 1  2017           69           1           71           2          3063728
# 2  2018           70           1           79           2          3063728
# 3  2019           57           1           47           2          3063728
# 4  2020           31           1           50           2          3063728
# 5  2021           55           1           42           2          3063728

# %%
df_1_ETL2_v5 = df_1_ETL2_v5.drop(['Semestre_x','Semestre_y'], axis=1)

# %%
df_1_ETL2_v5
# Out:
#    AAAA  VICTIMAS S1  VICTIMAS S2  Poblacion total
# 0  2016           65           81          3063728
# 1  2017           69           71          3063728
# 2  2018           70           79          3063728
# 3  2019           57           47          3063728
# 4  2020           31           50          3063728
# 5  2021           55           42          3063728

# %%
df_1_ETL2_v5['% VICTIMAS S1'] = (((df_1_ETL2_v5['VICTIMAS S1']) / (df_1_ETL2_v5['Poblacion total'])) * 100000).round(2)
df_1_ETL2_v5['% VICTIMAS S2'] = (((df_1_ETL2_v5['VICTIMAS S2']) / (df_1_ETL2_v5['Poblacion total'])) * 100000).round(2)
df_1_ETL2_v5['VICTIMAS TOTAL'] = ((df_1_ETL2_v5['VICTIMAS S1']) + (df_1_ETL2_v5['VICTIMAS S2']))
df_1_ETL2_v5['% VICTIMAS TOTAL'] = ((df_1_ETL2_v5['VICTIMAS S1']) + (df_1_ETL2_v5['VICTIMAS S2']) / (df_1_ETL2_v5['Poblacion total']) * 100000).round(2)

# %%
df_1_ETL2_v5
# Out:
#    AAAA  VICTIMAS S1  VICTIMAS S2  Poblacion total  % VICTIMAS S1  \
# 0  2016           65           81          3063728           2.12
# 1  2017           69           71          3063728           2.25
# 2  2018           70           79          3063728           2.28
# 3  2019           57           47          3063728           1.86
# 4  2020           31           50          3063728           1.01
# 5  2021           55           42          3063728           1.80
#
#    % VICTIMAS S2  VICTIMAS TOTAL  % VICTIMAS TOTAL
# 0           2.64             146             67.64
# 1           2.32             140             71.32
# 2           2.58             149             72.58
# 3           1.53             104             58.53
# 4           1.63              81             32.63
# 5           1.37              97             56.37

# %% [markdown]
# -------------------------------------------------------------

# %%
df_1_ETL2_2_v2 = df_1_ETL2.copy()

# %%
df_1_ETL2_2_v2 = df_1_ETL2_2_v2.groupby(['AAAA', 'MM', 'COMUNA'])['N_VICTIMAS'].sum().reset_index()

# %%
df_1_ETL2_2_v2
# Out:
#      AAAA  MM  COMUNA  N_VICTIMAS
# 0    2016   1       1           2
# 1    2016   1       8           3
# 2    2016   1       9           2
# 3    2016   1      11           1
# 4    2016   2       1           4
# ..    ...  ..     ...         ...
# 476  2021  12       7           1
# 477  2021  12       9           2
# 478  2021  12      10           1
# 479  2021  12      11           2
# 480  2021  12      13           1
#
# [481 rows x 4 columns]

# %%
df_1_ETL2_2_v3 = df_1_ETL2_2_v2.copy()

# %%
df_1_ETL2_2_v3_Sem1 = df_1_ETL2_2_v3[(df_1_ETL2_2_v3['MM'] >= 1) & (df_1_ETL2_2_v3['MM'] <= 6)]
df_1_ETL2_2_v3_Sem2 = df_1_ETL2_2_v3[(df_1_ETL2_2_v3['MM'] >= 7) & (df_1_ETL2_2_v3['MM'] <= 12)]

# %%
df_1_ETL2_2_v3_Sem1['MM'].value_counts()
# Out:
# MM
# 1    50
# 5    42
# 6    41
# 2    39
# 3    36
# 4    34
# Name: count, dtype: int64

# %%
df_1_ETL2_2_v3_Sem2['MM'].value_counts()
# Out:
# MM
# 12    48
# 11    45
# 8     40
# 10    36
# 7     35
# 9     35
# Name: count, dtype: int64

# %%
df_1_ETL2_2_v3_Sem1 = df_1_ETL2_2_v3_Sem1.rename(columns={"N_VICTIMAS": "VICTIMAS S1"})
df_1_ETL2_2_v3_Sem2 = df_1_ETL2_2_v3_Sem2.rename(columns={"N_VICTIMAS": "VICTIMAS S2"})

# %%
print(len(df_1_ETL2_2_v3_Sem1))
df_1_ETL2_2_v3_Sem1.head()
# Out:
# 242
#    AAAA  MM  COMUNA  VICTIMAS S1
# 0  2016   1       1            2
# 1  2016   1       8            3
# 2  2016   1       9            2
# 3  2016   1      11            1
# 4  2016   2       1            4

# %%
print(len(df_1_ETL2_2_v3_Sem2))
df_1_ETL2_2_v3_Sem2.head()
# Out:
# 239
#     AAAA  MM  COMUNA  VICTIMAS S2
# 40  2016   7       1            2
# 41  2016   7       3            1
# 42  2016   7       5            1
# 43  2016   7       6            1
# 44  2016   7       8            1

# %% [markdown]
# --------------------------------------------

# %%
df_gcba_2_v2 = df_gcba.copy()
df_gcba_2_v2
# Out:
#     COMUNA  POBLACION
# 0        1     253271
# 1        2     149720
# 2        3     192763
# 3        4     238809
# 4        5     186956
# 5        6     184846
# 6        7     240607
# 7        8     226649
# 8        9     170605
# 9       10     170282
# 10      11     189986
# 11      12     213914
# 12      13     235967
# 13      14     226944
# 14      15     182409

# %%
df_1_ETL2_2_v4_S1 = pd.merge(df_1_ETL2_2_v3_Sem1, df_gcba_2_v2, on='COMUNA')

df_1_ETL2_2_v4_S2 = pd.merge(df_1_ETL2_2_v3_Sem2, df_gcba_2_v2, on='COMUNA')

# %%
print(len(df_1_ETL2_2_v4_S1))
df_1_ETL2_2_v4_S1.head()
# Out:
# 242
#    AAAA  MM  COMUNA  VICTIMAS S1  POBLACION
# 0  2016   1       1            2     253271
# 1  2016   2       1            4     253271
# 2  2016   3       1            1     253271
# 3  2016   4       1            1     253271
# 4  2016   5       1            2     253271

# %%
print(len(df_1_ETL2_2_v4_S2))
df_1_ETL2_2_v4_S2.head()
# Out:
# 237
#    AAAA  MM  COMUNA  VICTIMAS S2  POBLACION
# 0  2016   7       1            2     253271
# 1  2016   8       1            2     253271
# 2  2016   9       1            1     253271
# 3  2016  10       1            1     253271
# 4  2016  11       1            2     253271

# %%
df_1_ETL2_2_v4_S1['% VICTIMAS S1'] = (((df_1_ETL2_2_v4_S1['VICTIMAS S1']) / (df_1_ETL2_2_v4_S1['POBLACION'])) * 100000).round(2)
df_1_ETL2_2_v4_S2['% VICTIMAS S2'] = (((df_1_ETL2_2_v4_S2['VICTIMAS S2']) / (df_1_ETL2_2_v4_S2['POBLACION'])) * 100000).round(2)

# %%
print(len(df_1_ETL2_2_v4_S1))
df_1_ETL2_2_v4_S1.head()
# Out:
# 242
#    AAAA  MM  COMUNA  VICTIMAS S1  POBLACION  % VICTIMAS S1
# 0  2016   1       1            2     253271           0.79
# 1  2016   2       1            4     253271           1.58
# 2  2016   3       1            1     253271           0.39
# 3  2016   4       1            1     253271           0.39
# 4  2016   5       1            2     253271           0.79

# %%
print(len(df_1_ETL2_2_v4_S2))
df_1_ETL2_2_v4_S2.head()
# Out:
# 237
#    AAAA  MM  COMUNA  VICTIMAS S2  POBLACION  % VICTIMAS S2
# 0  2016   7       1            2     253271           0.79
# 1  2016   8       1            2     253271           0.79
# 2  2016   9       1            1     253271           0.39
# 3  2016  10       1            1     253271           0.39
# 4  2016  11       1            2     253271           0.79

# %% [markdown]
# ---------------------------------------------------------------------

# %%
df_1_ETL2_3 =  df_1_ETL2.copy()

# %%
print(len(df_1_ETL2_3))
df_1_ETL2_3.head()
# Out:
# 696
#    Unnamed: 0         ID  N_VICTIMAS       FECHA  AAAA  MM  DD      HORA HH  \
# 0           0  2016-0001           1  2016-01-01  2016   1   1  04:00:00  4
# 1           1  2016-0002           1  2016-01-02  2016   1   2  01:15:00  1
# 2           2  2016-0003           1  2016-01-03  2016   1   3  07:00:00  7
# 3           3  2016-0004           1  2016-01-10  2016   1  10  00:00:00  0
# 4           4  2016-0005           1  2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE             Calle  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  PIEDRA BUENA AV.
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ    PAZ, GRAL. AV.
# 2                         AV ENTRE RIOS 2034       AVENIDA    ENTRE RIOS AV.
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA    LARRAZABAL AV.
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA      SAN JUAN AV.
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                            Sin Cruce
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada  COMUNA   PARTICIPANTES  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...       8       MOTO-AUTO
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.       9  AUTO-PASAJEROS
# 2                                ENTRE RIOS AV. 2034       1       MOTO-AUTO
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.       8         MOTO-SD
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.       1  MOTO-PASAJEROS
#
#   VICTIMA    ACUSADO
# 0    MOTO       AUTO
# 1    AUTO  PASAJEROS
# 2    MOTO       AUTO
# 3    MOTO         SD
# 4    MOTO  PASAJEROS

# %%
df_1_ETL2_3_v2 = df_1_ETL2_3[df_1_ETL2_3["VICTIMA"] == "MOTO"]

# %%
print(len(df_1_ETL2_3_v2))
df_1_ETL2_3_v2.head()
# Out:
# 295
#    Unnamed: 0         ID  N_VICTIMAS       FECHA  AAAA  MM  DD      HORA  HH  \
# 0           0  2016-0001           1  2016-01-01  2016   1   1  04:00:00   4
# 2           2  2016-0003           1  2016-01-03  2016   1   3  07:00:00   7
# 3           3  2016-0004           1  2016-01-10  2016   1  10  00:00:00   0
# 4           4  2016-0005           1  2016-01-21  2016   1  21  05:20:00   5
# 5           5  2016-0008           1  2016-01-24  2016   1  24  18:30:00  18
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE              Calle  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA   PIEDRA BUENA AV.
# 2                         AV ENTRE RIOS 2034       AVENIDA     ENTRE RIOS AV.
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA     LARRAZABAL AV.
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA       SAN JUAN AV.
# 5             AV 27 DE FEBRERO Y AV ESCALADA       AVENIDA  27 DE FEBRERO AV.
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 2                            Sin Cruce
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
# 5                         ESCALADA AV.
#
#                                Dirección Normalizada  COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...       8
# 2                                ENTRE RIOS AV. 2034       1
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.       8
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.       1
# 5                   27 DE FEBRERO AV. y ESCALADA AV.       8
#
#       PARTICIPANTES VICTIMA      ACUSADO
# 0         MOTO-AUTO    MOTO         AUTO
# 2         MOTO-AUTO    MOTO         AUTO
# 3           MOTO-SD    MOTO           SD
# 4    MOTO-PASAJEROS    MOTO    PASAJEROS
# 5  MOTO-OBJETO FIJO    MOTO  OBJETO FIJO

# %%
df_1_ETL2_3_v3 = df_1_ETL2_3_v2.groupby(['AAAA'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_3_v3))
df_1_ETL2_3_v3.head(10)
# Out:
# 6
#    AAAA  N_VICTIMAS
# 0  2016          65
# 1  2017          56
# 2  2018          57
# 3  2019          50
# 4  2020          28
# 5  2021          46

# %%
df_1_ETL2_3_v4 = df_1_ETL2_3_v3.copy()

# %%
lista_calculo = []

for x in range(5):

    calculo = (((df_1_ETL2_3_v4.iloc[x]['N_VICTIMAS'] - df_1_ETL2_3_v4.iloc[x + 1]['N_VICTIMAS']) / (df_1_ETL2_3_v4.iloc[x]['N_VICTIMAS'])) * 100).round(2)
    
    lista_calculo.append(calculo * -1)

# %%
lista_calculo
# Out:
# [-13.85, 1.79, -12.28, -44.0, 64.29]

# %%
df_1_ETL2_3_v5 = df_1_ETL2_3_v4.copy()

# %%
for x in range(5):
    df_1_ETL2_3_v5.loc[x + 1, 'Variacion'] = lista_calculo[x]

# %%
df_1_ETL2_3_v5["Variacion"].replace(to_replace=np.nan, value=0, inplace=True)

# %%
df_1_ETL2_3_v5
# Out:
#    AAAA  N_VICTIMAS  Variacion
# 0  2016          65       0.00
# 1  2017          56     -13.85
# 2  2018          57       1.79
# 3  2019          50     -12.28
# 4  2020          28     -44.00
# 5  2021          46      64.29

# %% [markdown]
# -------------------------------------

# %%
with pd.ExcelWriter('Archivos\data_homicidios.xlsx') as writer:
    
    df_1_ETL2_v5.to_excel(writer, sheet_name='KPI_1', index=False)
    df_1_ETL2_2_v4_S1.to_excel(writer, sheet_name='KPI_1_x_COMUNA_S1', index=False)
    df_1_ETL2_2_v4_S2.to_excel(writer, sheet_name='KPI_1_x_COMUNA_S2', index=False)
    df_1_ETL2_3_v5.to_excel(writer, sheet_name='KPI_2', index=False)

# %% [markdown]
# ----------------------------------------------------------

# %%
df_1_ETL2.head()
# Out:
#    Unnamed: 0         ID  N_VICTIMAS       FECHA  AAAA  MM  DD      HORA HH  \
# 0           0  2016-0001           1  2016-01-01  2016   1   1  04:00:00  4
# 1           1  2016-0002           1  2016-01-02  2016   1   2  01:15:00  1
# 2           2  2016-0003           1  2016-01-03  2016   1   3  07:00:00  7
# 3           3  2016-0004           1  2016-01-10  2016   1  10  00:00:00  0
# 4           4  2016-0005           1  2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE             Calle  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  PIEDRA BUENA AV.
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ    PAZ, GRAL. AV.
# 2                         AV ENTRE RIOS 2034       AVENIDA    ENTRE RIOS AV.
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA    LARRAZABAL AV.
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA      SAN JUAN AV.
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                            Sin Cruce
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada  COMUNA   PARTICIPANTES  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...       8       MOTO-AUTO
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.       9  AUTO-PASAJEROS
# 2                                ENTRE RIOS AV. 2034       1       MOTO-AUTO
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.       8         MOTO-SD
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.       1  MOTO-PASAJEROS
#
#   VICTIMA    ACUSADO
# 0    MOTO       AUTO
# 1    AUTO  PASAJEROS
# 2    MOTO       AUTO
# 3    MOTO         SD
# 4    MOTO  PASAJEROS

# %%
df_1_ETL2_4_v1 = df_1_ETL2.copy()

# %%
df_1_ETL2_4_v1 = df_1_ETL2_4_v1.groupby(['AAAA', 'VICTIMA'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_4_v1))
df_1_ETL2_4_v1.head()
# Out:
# 37
#    AAAA    VICTIMA  N_VICTIMAS
# 0  2016       AUTO          18
# 1  2016  BICICLETA           4
# 2  2016     CARGAS           3
# 3  2016       MOTO          65
# 4  2016      MOVIL           1

# %%
df_1_ETL2_4_v2 = df_1_ETL2.copy()

# %%
df_1_ETL2_4_v2 = df_1_ETL2_4_v2.groupby(['VICTIMA'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_4_v2))
df_1_ETL2_4_v2.head()
# Out:
# 10
#      VICTIMA  N_VICTIMAS
# 0       AUTO          92
# 1  BICICLETA          29
# 2     CARGAS           7
# 3       MOTO         302
# 4      MOVIL           3

# %%
df_1_ETL2_5_v1 = df_1_ETL2.copy()

# %%
df_1_ETL2_5_v1 = df_1_ETL2_5_v1.groupby(['AAAA', 'MM'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_5_v1))
df_1_ETL2_5_v1.head()
# Out:
# 72
#    AAAA  MM  N_VICTIMAS
# 0  2016   1           8
# 1  2016   2          12
# 2  2016   3          13
# 3  2016   4          11
# 4  2016   5           7

# %%
df_1_ETL2_5_v2 = df_1_ETL2.copy()

# %%
df_1_ETL2_5_v2 = df_1_ETL2_5_v2.groupby(['MM'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_5_v2))
df_1_ETL2_5_v2.head()
# Out:
# 12
#    MM  N_VICTIMAS
# 0   1          62
# 1   2          59
# 2   3          56
# 3   4          52
# 4   5          60

# %%
df_1_ETL2_6_v1 = df_1_ETL2.copy()

# %%
df_1_ETL2_6_v1 = df_1_ETL2_6_v1.groupby(['AAAA', 'DD'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_6_v1))
df_1_ETL2_6_v1.head(5)
# Out:
# 180
#    AAAA  DD  N_VICTIMAS
# 0  2016   1           1
# 1  2016   2           5
# 2  2016   3           5
# 3  2016   4           6
# 4  2016   5           1

# %%
df_1_ETL2_6_v2 = df_1_ETL2.copy()

# %%
df_1_ETL2_6_v2 = df_1_ETL2_6_v2.groupby(['DD'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_6_v2))
df_1_ETL2_6_v2.head(5)
# Out:
# 31
#    DD  N_VICTIMAS
# 0   1          18
# 1   2          24
# 2   3          28
# 3   4          23
# 4   5          19

# %%
df_1_ETL2_7_v1 = df_1_ETL2.copy()

# %%
df_1_ETL2_7_v1 = df_1_ETL2_7_v1.groupby(['AAAA', 'Calle'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_7_v1))
df_1_ETL2_7_v1.head(5)
# Out:
# 484
#    AAAA                       Calle  N_VICTIMAS
# 0  2016           27 DE FEBRERO AV.           4
# 1  2016              9 DE JULIO AV.           1
# 2  2016             ACOSTA, MARIANO           2
# 3  2016  ALBERDI, JUAN BAUTISTA AV.           4
# 4  2016        ALCORTA, AMANCIO AV.           3

# %%
df_1_ETL2_8_v1 = df_1_ETL2.copy()

# %%
df_1_ETL2_8_v1 = df_1_ETL2_8_v1.groupby(['Calle'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_8_v1))
df_1_ETL2_8_v1.head(5)
# Out:
# 280
#                       Calle  N_VICTIMAS
# 0  11 DE SEPTIEMBRE DE 1888           1
# 1   15 DE NOVIEMBRE DE 1889           2
# 2           24 DE NOVIEMBRE           3
# 3         27 DE FEBRERO AV.           8
# 4            9 DE JULIO AV.           5

# %%
df_1_ETL2_9_v1 = df_1_ETL2.copy()

# %%
df_1_ETL2_9_v1 = df_1_ETL2_9_v1.groupby(['COMUNA'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_9_v1))
df_1_ETL2_9_v1.head(5)
# Out:
# 16
#    COMUNA  N_VICTIMAS
# 0       0           2
# 1       1          93
# 2       2          25
# 3       3          46
# 4       4          79

# %%
df_1_ETL2_10_v1 = df_1_ETL2.copy()

# %%
df_1_ETL2_10_v1 = df_1_ETL2_10_v1.groupby(['AAAA', 'COMUNA'])['N_VICTIMAS'].sum().reset_index()

# %%
print(len(df_1_ETL2_10_v1))
df_1_ETL2_10_v1.head(5)
# Out:
# 91
#    AAAA  COMUNA  N_VICTIMAS
# 0  2016       0           2
# 1  2016       1          22
# 2  2016       2           1
# 3  2016       3           8
# 4  2016       4          16
